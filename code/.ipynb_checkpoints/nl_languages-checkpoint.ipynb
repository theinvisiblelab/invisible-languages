# %%
import re
from bs4 import BeautifulSoup
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
def extract_numeric_users(text):
    # Use a regex to find a number with commas (e.g., "7,500")
    match = re.search(r'([\d,]+)', text)
    if match:
        # Remove commas and convert to int
        return int(match.group(1).replace(',', ''))
    return None

def clean_text(text):
    # Remove a trailing dot if present
    return text.rstrip('.') if text.endswith('.') else text

# %%
# Open and read the HTML file
with open('../data/nl_ethno.html', 'r', encoding='utf-8') as f:
    html = f.read()

# Parse the HTML content
soup = BeautifulSoup(html, 'html.parser')

# Find the languages section using the section id "languages"
languages_section = soup.find('section', id='languages')

# Find all language header blocks
language_headers = languages_section.find_all('div', class_='languages__label entry__label')

# %%
languages_data = []

# Loop over each language header block
for header in language_headers:
    # Extract language name (assuming the first text node is the name)
    language_name = header.contents[0].strip() if header.contents else None

    # Extract the language code from the <a> tag inside the header
    code_tag = header.find('a', class_='chip')
    language_code = code_tag.get_text(strip=True) if code_tag else None

    # Find the corresponding details block: the next <ul> with class "languages__content entry__content"
    details_ul = header.find_next_sibling('ul', class_='languages__content entry__content')

    details = {}
    
    if details_ul:
        # Each detail is indicated by an <i> tag and the following text
        for i_tag in details_ul.find_all('i'):
            # The key is the text in the <i> tag (without the trailing colon)
            key = i_tag.get_text(strip=True).rstrip(':')
            value = ""
            next_sibling = i_tag.next_sibling
            if next_sibling:
                value = next_sibling.strip()
            
            # For certain keys, remove a trailing dot
            if key in {"Location", "Status", "Alternate Names", "Autonym", "Classification"}:
                value = clean_text(value)
            
            # For Users, extract the numeric value
            if key == "Users":
                numeric_value = extract_numeric_users(value)
                details[key] = numeric_value
            else:
                details[key] = value

    # Combine language name, code, and details into a single dict
    lang_entry = {
        'Language': language_name,
        'Code': language_code,
    }
    lang_entry.update(details)
    languages_data.append(lang_entry)

# Create a pandas DataFrame
df = pd.DataFrame(languages_data)

# Sort the DataFrame by the "Users" column (if present) in ascending order
if 'Users' in df.columns:
    df.sort_values('Users', inplace=True)


# Desired column order
new_order = ['Language', 'Classification', 'Status', 'Users', 'Location', 'Code', 'Alternate Names', 'Autonym']
df = df[new_order]

# Drop index and display the DataFrame
df = df.reset_index(drop = True)

df
# Out:
#                             Language  \
# 0               Chaldean Neo-Aramaic
# 1                      Romani, Sinte
# 2                              Khmer
# 3                              Malay
# 4                            Burmese
# 5                        Kinyarwanda
# 6                              Wolof
# 7                 Estonian, Standard
# 8                             Nepali
# 9                     Arabic, Libyan
# 10                             Tajik
# 11                             Tigré
# 12                            Turoyo
# 13                       Chinese, Wu
# 14                    Albanian, Tosk
# 15                     Stellingwerfs
# 16                         Norwegian
# 17                           Finnish
# 18                            Danish
# 19                        Macedonian
# 20                             Tamil
# 21                           Swedish
# 22                           Bengali
# 23                 Armenian, Western
# 24                 Latvian, Standard
# 25                  Arabic, Sudanese
# 26                    Albanian, Gheg
# 27                            Korean
# 28                          Japanese
# 29                            Hebrew
# 30                            Slovak
# 31                  Arabic, Tunisian
# 32                             Czech
# 33                        Lithuanian
# 34                          Croatian
# 35              Guinea-Bissau Creole
# 36                           Serbian
# 37                           Sinhala
# 38                  Pashto, Southern
# 39                          Bavarian
# 40                              Urdu
# 41                              Akan
# 42  Sign Language of the Netherlands
# 43                         Ukrainian
# 44                              Thai
# 45                      Kabuverdianu
# 46                        Vietnamese
# 47                          Tigrigna
# 48                           Tagalog
# 49                           Amharic
# 50                           Italian
# 51                         Afrikaans
# 52                  Arabic, Egyptian
# 53                         Hungarian
# 54                             Greek
# 55                      Chinese, Yue
# 56                             Hindi
# 57                           Russian
# 58                           Bosnian
# 59                  Persian, Iranian
# 60                            Somali
# 61                          Javanese
# 62                         Bulgarian
# 63                 Chinese, Mandarin
# 64                   Malay, Ambonese
# 65                              Dari
# 66                          Romanian
# 67                        Portuguese
# 68              Arabic, Mesopotamian
# 69                 Kurdish, Northern
# 70                        Papiamentu
# 71                  Arabic, Algerian
# 72                            Zeeuws
# 73                 Arabic, Levantine
# 74                      West Flemish
# 75               Hindustani, Sarnami
# 76                           Tarifit
# 77                            Veluws
# 78                       Achterhoeks
# 79                            Polish
# 80                            Drents
# 81                          Gronings
# 82                           Turkish
# 83                            Twents
# 84                          Sallands
# 85                        Indonesian
# 86                      Sranan Tongo
# 87                  Arabic, Moroccan
# 88                        Limburgish
# 89                           Frisian
# 90                           Spanish
# 91                            French
# 92                  German, Standard
# 93                           English
# 94                             Dutch
#
#                                        Classification  \
# 0   Afro-Asiatic, Semitic, Central, Aramaic, Easte...
# 1   Indo-European, Indo-Iranian, Indo-Aryan, Inter...
# 2   Austro-Asiatic, Mon-Khmer, Eastern Mon-Khmer, ...
# 3   Austronesian, Malayo-Polynesian, Malayo-Chamic...
# 4   Sino-Tibetan, Tibeto-Burman, Ngwi-Burmese, Bur...
# 5   Niger-Congo, Atlantic-Congo, Volta-Congo, Benu...
# 6   Niger-Congo, Atlantic-Congo, Atlantic, Norther...
# 7                                      Uralic, Finnic
# 8   Indo-European, Indo-Iranian, Indo-Aryan, Inter...
# 9       Afro-Asiatic, Semitic, Central, South, Arabic
# 10  Indo-European, Indo-Iranian, Iranian, Western,...
# 11     Afro-Asiatic, Semitic, South, Ethiopian, North
# 12  Afro-Asiatic, Semitic, Central, Aramaic, Easte...
# 13                              Sino-Tibetan, Chinese
# 14                      Indo-European, Albanian, Tosk
# 15  Indo-European, Germanic, West, Low Saxon-Low F...
# 16  Indo-European, Germanic, North, East Scandinav...
# 17                                     Uralic, Finnic
# 18  Indo-European, Germanic, North, East Scandinav...
# 19  Indo-European, Balto-Slavic, Slavic, South, Ea...
# 20  Dravidian, Southern, Tamil-Kannada, Tamil-Koda...
# 21  Indo-European, Germanic, North, East Scandinav...
# 22  Indo-European, Indo-Iranian, Indo-Aryan, Outer...
# 23                            Indo-European, Armenian
# 24       Indo-European, Balto-Slavic, Baltic, Eastern
# 25      Afro-Asiatic, Semitic, Central, South, Arabic
# 26                      Indo-European, Albanian, Gheg
# 76                                      Unestablished    166000
# 77                                     6a* (Vigorous)    175000
# 78                                    5* (Developing)    211000
# 79                                      Unestablished    221000
# 80                                    5* (Developing)    255000
# 81                                    5* (Developing)    262000
# 82                                      Unestablished    308000
# 83                                    5* (Developing)    334000
# 84                                     6a* (Vigorous)    347000
# 85                                      Unestablished    349000
# 86                                      Unestablished    368000
# 87                                      Unestablished    428000
# 88  5 (Developing). Statutory language of provinci...    700000
# 89  2 (Provincial). Statutory provincial language ...    718000
# 90                                     5* (Dispersed)    774000
# 91                                     5* (Dispersed)   3441100
# 92                                     5* (Dispersed)  12743000
# 93                                    4 (Educational)  15805000
# 94           1 (National). De facto national language  16400000
#
#                                              Location Code  \
# 0                                                 NaN  cld
# 1                                                 NaN  rmo
# 2                                                 NaN  khm
# 3                                                 NaN  zlm
# 4                                                 NaN  mya
# 5                                                 NaN  kin
# 6                                                 NaN  wol
# 7                                                 NaN  ekk
# 8                                                 NaN  npi
# 9                                                 NaN  ayl
# 10                                                NaN  tgk
# 11                                                NaN  tig
# 12                                                NaN  tru
# 13                                                NaN  wuu
# 14                                                NaN  als
# 15  Friesland province: Stellingwerven region, Oos...  stl
# 16                                                NaN  nor
# 17                                                NaN  fin
# 18                                                NaN  dan
# 19                                                NaN  mkd
# 20                                                NaN  tam
# 21                                                NaN  swe
# 22                                                NaN  ben
# 23                                                NaN  hyw
# 24                                                NaN  lvs
# 25                                                NaN  apd
# 26                                                NaN  aln
# 27                                                NaN  kor
# 28                                                NaN  jpn
# 29                                                NaN  heb
# 30                                                NaN  slk
# 31                                                NaN  aeb
# 32                                                NaN  ces
# 33                                                NaN  lit
# 34                                                NaN  hrv
# 35                                                NaN  pov
# 36                                                NaN  srp
# 37                                                NaN  sin
# 38                                                NaN  pbt
# 39                                                NaN  bar
# 40                                                NaN  urd
# 41                                                NaN  aka
# 42                                          Scattered  dse
# 43                                                NaN  ukr
# 44                                                NaN  tha
# 45                                                NaN  kea
# 46                                                NaN  vie
# 47                                                NaN  tir
# 48                                                NaN  tgl
# 49                                                NaN  amh
# 50                                                NaN  ita
# 51                                                NaN  afr
# 52                                                NaN  arz
# 53                                                NaN  hun
# 54                                                NaN  ell
# 55                                                NaN  yue
# 56                                                NaN  hin
# 57                                                NaN  rus
# 58                                                NaN  bos
# 59                                                NaN  pes
# 60                                                NaN  som
# 61                                                NaN  jav
# 62                                                NaN  bul
# 63                                                NaN  cmn
# 64                                                NaN  abs
# 65                                                NaN  prs
# 66                                                NaN  ron
# 67                                                NaN  por
# 68                                                NaN  acm
# 69                                                NaN  kmr
# 70                                                NaN  pap
# 71                                                NaN  arq
# 72  South Holland and Zeeland provinces. Rhine-Sch...  zea
# 73                                                NaN  apc
# 74                                   Zeeland province  vls
# 75                                                NaN  hns
# 76                                                NaN  rif
# 77                                Gelderland province  vel
# 78                                Gelderland province  act
# 79                                                NaN  pol
# 80  Drenthe province: near German border; Overijss...  drt
# 81  Drenthe and Groningen provinces: Bellingwedde,...  gos
# 82                                                NaN  tur
# 83                               Overijssels province  twd
# 84                     Overijssels province: Sallands  sdz
# 85                                                NaN  ind
# 86                                                NaN  srn
# 87                                                NaN  ary
# 88  Limburg province: Heerlen, Maastricht, Roermon...  lim
# 89  Friesland province; Groningen province: De Mar...  fry
# 90                                                NaN  spa
# 91                                         Widespread  fra
# 92                                                NaN  deu
# 93                                         Widespread  eng
# 94                                                NaN  nld
#
#                                       Alternate Names        Autonym
# 0                                                 NaN            NaN
# 1                               Romanes, Sinte, Sinti            NaN
# 2                                                 NaN            NaN
# 3                                                 NaN            NaN
# 4                                                 NaN            NaN
# 5                                                 NaN            NaN
# 6                                                 NaN            NaN
# 7                                                 NaN            NaN
# 8                                                 NaN            NaN
# 9                                                 NaN            NaN
# 10                                                NaN            NaN
# 11                                                NaN            NaN
# 12                                                NaN            NaN
# 13                                                NaN            NaN
# 14                                                NaN            NaN
# 15                                       Stellingwerf  Stellingwarfs
# 16                                                NaN            NaN
# 17                                                NaN            NaN
# 18                                                NaN            NaN
# 19                                                NaN            NaN
# 20                                                NaN            NaN
# 21                                                NaN            NaN
# 22                                                NaN            NaN
# 23                                                NaN            NaN
# 24                                                NaN            NaN
# 25                                                NaN            NaN
# 26                                                NaN            NaN
# 27                                                NaN            NaN
# 28                                                NaN            NaN
# 29                                                NaN            NaN
# 30                                                NaN            NaN
# 31                                                NaN            NaN
# 32                                                NaN            NaN
# 33                                                NaN            NaN
# 34                                                NaN            NaN
# 35                                                NaN            NaN
# 36                                                NaN            NaN
# 37                                                NaN            NaN
# 38                                                NaN            NaN
# 39                                                NaN            NaN
# 40                                                NaN            NaN
# 41                                                NaN            NaN
# 42  Dutch Sign Language, NGT, Nederlandse Gebarent...            NaN
# 43                                                NaN            NaN
# 44                                                NaN            NaN
# 45                                                NaN            NaN
# 46                                                NaN            NaN
# 47                                                NaN            NaN
# 48                                                NaN            NaN
# 49                                                NaN            NaN
# 50                                                NaN            NaN
# 51                                                NaN            NaN
# 52                                                NaN            NaN
# 53                                                NaN            NaN
# 54                                                NaN            NaN
# 55                                                NaN            NaN
# 56                                                NaN            NaN
# 57                                                NaN            NaN
# 58                                                NaN            NaN
# 59                                                NaN            NaN
# 60                                                NaN            NaN
# 61                                                NaN            NaN
# 62                                                NaN            NaN
# 63                                                NaN            NaN
# 64                                                NaN            NaN
# 65                                                NaN            NaN
# 66                                                NaN            NaN
# 67                                                NaN            NaN
# 68                                                NaN            NaN
# 69                                                NaN            NaN
# 70                                          Papiments            NaN
# 71                                                NaN            NaN
# 72                                   Zeaws, Zeelandic         Zeêuws
# 73                                                NaN            NaN
# 74                    Vlaams, West Vlaams, West-Vlams            NaN
# 75                                                NaN            NaN
# 76                                                NaN            NaN
# 77                                             Veluwe            NaN
# 78               Aachterhoeks, Achterhoek, Winterwiek    Achterhooks
# 79                                                NaN            NaN
# 80                   Dreins, Dreints, Drente, Drenthe        Drèents
# 81                     Groningen, Grunnings, Grönnegs       Grunnegs
# 82                                                NaN            NaN
# 83                                             Twente         Twents
# 84                                    Sallan, Salland            NaN
# 85                                                NaN            NaN
# 86                                                NaN            NaN
# 87                                                NaN            NaN
# 88  Limberger, Limburgan, Limburgian, Limburgic, L...       Lèmburgs
# 89                           Fries, Westlauwers Fries          Frysk
# 90                                                NaN            NaN
# 91                                                NaN            NaN
# 92                                            Deutsch            NaN
# 93                                             Engels            NaN
# 94                                                NaN     Nederlands
